# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd

# %%
main_url = 'https://forums.developer.nvidia.com'

# %%
page = requests.get(main_url)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
all_links = soup.find_all("a", href=True)

# Extract and print the URLs of all links
for link in all_links:
    print(link['href'])
# Out:
# /
# /c/community-information/83
# /c/regional/611
# /c/blogs-events/283
# /c/agx-autonomous-machines/55
# /c/autonomous-vehicles/517
# /c/ai-data-science/86
# /c/accelerated-computing/5
# /c/healthcare/149
# /c/gaming-and-visualization-technologies/192
# /c/developer-tools/106
# /c/gpu-graphics/145
# /c/omniverse/300
# /c/infrastructure/369
# /c/physics-simulation/442
# /c/nvidia-virtual-gpu-forums/328
# /
# /categories
# /guidelines
# https://www.nvidia.com/en-us/about-nvidia/legal-info/
# https://www.nvidia.com/en-us/about-nvidia/privacy-policy/
# https://www.discourse.org
# https://www.nvidia.com/en-us/about-nvidia/legal-info/
# https://developer.nvidia.com/legal/terms
# https://www.nvidia.com/en-us/about-nvidia/privacy-policy/
# https://developer.nvidia.com/contact
# https://www.nvidia.com/en-us/about-nvidia/privacy-policy/

# %%
page_links_forum = []
for link in all_links:
    if str(link['href']).startswith('https:') == False:
        page_links_forum.append(main_url+link['href'])

# %%
page_links_forum
# Out:
# ['https://forums.developer.nvidia.com/',
#  'https://forums.developer.nvidia.com/c/community-information/83',
#  'https://forums.developer.nvidia.com/c/regional/611',
#  'https://forums.developer.nvidia.com/c/blogs-events/283',
#  'https://forums.developer.nvidia.com/c/agx-autonomous-machines/55',
#  'https://forums.developer.nvidia.com/c/autonomous-vehicles/517',
#  'https://forums.developer.nvidia.com/c/ai-data-science/86',
#  'https://forums.developer.nvidia.com/c/accelerated-computing/5',
#  'https://forums.developer.nvidia.com/c/healthcare/149',
#  'https://forums.developer.nvidia.com/c/gaming-and-visualization-technologies/192',
#  'https://forums.developer.nvidia.com/c/developer-tools/106',
#  'https://forums.developer.nvidia.com/c/gpu-graphics/145',
#  'https://forums.developer.nvidia.com/c/omniverse/300',
#  'https://forums.developer.nvidia.com/c/infrastructure/369',
#  'https://forums.developer.nvidia.com/c/physics-simulation/442',
#  'https://forums.developer.nvidia.com/c/nvidia-virtual-gpu-forums/328',
#  'https://forums.developer.nvidia.com/',
#  'https://forums.developer.nvidia.com/categories',
#  'https://forums.developer.nvidia.com/guidelines']

# %%
page_links_forum = page_links_forum[1:]

# %%
page_links_forum_names = [str(x).split('/')[-2] for x in page_links_forum]

# %%
page_links_forum_names
# Out:
# ['community-information',
#  'regional',
#  'blogs-events',
#  'agx-autonomous-machines',
#  'autonomous-vehicles',
#  'ai-data-science',
#  'accelerated-computing',
#  'healthcare',
#  'gaming-and-visualization-technologies',
#  'developer-tools',
#  'gpu-graphics',
#  'omniverse',
#  'infrastructure',
#  'physics-simulation',
#  'nvidia-virtual-gpu-forums',
#  'forums.developer.nvidia.com',
#  'forums.developer.nvidia.com',
#  'forums.developer.nvidia.com']

# %%
url = page_links_forum[11]




page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
temp = soup.find_all("a", href=True)

for link in temp:
    print(link['href'])
# Out:
# /
# /c/omniverse/300
# /c/omniverse/simulation/69
# /c/omniverse/general-discussion/329
# /c/omniverse/apps/398
# /c/omniverse/announcements/302
# /c/omniverse/showcase/362
# /c/omniverse/digital-humans/485
# /c/omniverse/extension/399
# /c/omniverse/connectors/380
# /c/omniverse/developer/330
# /c/omniverse/platform/397
# /c/omniverse/synthetic-data-generation-sdg/595
# /c/omniverse/services/608
# https://forums.developer.nvidia.com/t/audio2face-emotions-in-streaming-livelink-error/262343
# /c/omniverse/apps/audio2face/404
# https://forums.developer.nvidia.com/tag/unreal-5
# https://forums.developer.nvidia.com/u/romankupkovic1
# https://forums.developer.nvidia.com/t/how-to-listen-to-audio2face-livelink-server-in-python/262340
# /c/omniverse/apps/audio2face/404
# https://forums.developer.nvidia.com/tag/audio2face
# https://forums.developer.nvidia.com/u/yash11
# https://forums.developer.nvidia.com/t/help-while-installing-usd-composer-it-stays-stuck-on-installing/262328
# /c/omniverse/apps/create/405
# https://forums.developer.nvidia.com/u/domenico.grillo4
# https://forums.developer.nvidia.com/u/Richard3D
# https://forums.developer.nvidia.com/t/audio-to-gesture-to-metahuman-workflow-fingers-fix/261487
# /c/omniverse/apps/machinima/407
# https://forums.developer.nvidia.com/tag/unreal-engine
# https://forums.developer.nvidia.com/u/ayushsahai0074
# https://forums.developer.nvidia.com/u/esusantolim
# https://forums.developer.nvidia.com/u/Simplychenable
# https://forums.developer.nvidia.com/u/lhalper
# https://forums.developer.nvidia.com/t/cannot-delete-the-folders-from-nucleus/220627
# /c/omniverse/platform/nucleus/402
# https://forums.developer.nvidia.com/u/frank_liu
# https://forums.developer.nvidia.com/u/mkarlsson
# https://forums.developer.nvidia.com/u/frankt
# https://forums.developer.nvidia.com/u/rodolphe.assere
# https://forums.developer.nvidia.com/u/dlindsey
# https://forums.developer.nvidia.com/t/nucleus-server-doesnot-have-any-services/262284
# /c/omniverse/platform/nucleus/402
# https://forums.developer.nvidia.com/tag/local-host
# https://forums.developer.nvidia.com/tag/nucleus
# https://forums.developer.nvidia.com/tag/audio2face
# https://forums.developer.nvidia.com/u/mohit.sood.chicmic.off
# https://forums.developer.nvidia.com/u/dlindsey
# https://forums.developer.nvidia.com/t/isaac-sim-import-fbx-but-no-textures/241110
# /c/omniverse/simulation/69
# https://forums.developer.nvidia.com/u/a0939890213
# https://forums.developer.nvidia.com/u/agrant3d
# https://forums.developer.nvidia.com/u/felipe.cunha1
# https://forums.developer.nvidia.com/u/rthaker
# https://forums.developer.nvidia.com/u/jacob.eckert1
# https://forums.developer.nvidia.com/t/enable-cad-converter-extension/262311
# /c/omniverse/simulation/69
# https://forums.developer.nvidia.com/tag/cad
# https://forums.developer.nvidia.com/u/nickbakker40
# https://forums.developer.nvidia.com/t/code-2023-1-1-crashes-when-running-headless/262309
# /c/omniverse/synthetic-data-generation-sdg/595
# https://forums.developer.nvidia.com/u/julian.grimm
# https://forums.developer.nvidia.com/t/new-release/257725
# /c/omniverse/synthetic-data-generation-sdg/595
# https://forums.developer.nvidia.com/u/christof.schuetzenhoefer
# https://forums.developer.nvidia.com/u/pcallender
# https://forums.developer.nvidia.com/u/julian.grimm
# https://forums.developer.nvidia.com/t/how-to-solve-graph-composer-startup-errors/262290
# /c/omniverse/simulation/69
# https://forums.developer.nvidia.com/tag/ubuntu
# https://forums.developer.nvidia.com/tag/graph-composer
# https://forums.developer.nvidia.com/u/77438441
# https://forums.developer.nvidia.com/u/Simplychenable
# https://forums.developer.nvidia.com/t/trouble-in-moveit2/262172
# /c/omniverse/simulation/69
# https://forums.developer.nvidia.com/tag/docker
# https://forums.developer.nvidia.com/u/gaozhao22
# https://forums.developer.nvidia.com/t/getting-omniverse-flow-output-annotated/253268
# /c/omniverse/synthetic-data-generation-sdg/595
# https://forums.developer.nvidia.com/u/guydada
# https://forums.developer.nvidia.com/u/pcallender
# https://forums.developer.nvidia.com/u/shahizat
# https://forums.developer.nvidia.com/t/i-still-see-black-reflections/256621
# /c/omniverse/apps/create/405
# https://forums.developer.nvidia.com/u/pekka.varis
# https://forums.developer.nvidia.com/u/DavidDPD
# https://forums.developer.nvidia.com/u/Simplychenable
# https://forums.developer.nvidia.com/u/fsheng21
# https://forums.developer.nvidia.com/u/karol.osinski
# https://forums.developer.nvidia.com/t/unclear-unit-update-simulation-elapsed-time/261843
# /c/omniverse/developer/330
# https://forums.developer.nvidia.com/tag/physics
# https://forums.developer.nvidia.com/tag/physx
# https://forums.developer.nvidia.com/u/claudius.rimmele
# https://forums.developer.nvidia.com/u/AlesBorovicka
# https://forums.developer.nvidia.com/t/having-low-hit-rate-using-isaac-sim-on-window/262263
# /c/omniverse/simulation/69
# https://forums.developer.nvidia.com/u/infolok747
# https://forums.developer.nvidia.com/t/trouble-in-saving-map-when-i-follow-tutorial-for-visual-slam-with-isaac-sim/262258
# /c/omniverse/simulation/69
# https://forums.developer.nvidia.com/tag/slam
# https://forums.developer.nvidia.com/u/gaozhao22
# https://forums.developer.nvidia.com/t/blender-3-6-1-nucleus-unsupported/262254
# /c/omniverse/apps/blender/392
# https://forums.developer.nvidia.com/u/hombrezoo
# https://forums.developer.nvidia.com/t/omniverse-xr-blurry-vr-scene/234809
# /c/omniverse/apps/omniverse-xr/587
# https://forums.developer.nvidia.com/u/helmreich
# https://forums.developer.nvidia.com/u/WendyGram
# https://forums.developer.nvidia.com/u/barizon
# https://forums.developer.nvidia.com/u/OmerShapira
# https://forums.developer.nvidia.com/u/tsosnoski
# https://forums.developer.nvidia.com/t/with-4-vdb-s-composer-is-still-crashing-quite-a-lot/262232
# /c/omniverse/apps/create/405
# https://forums.developer.nvidia.com/u/pekka.varis
# https://forums.developer.nvidia.com/t/audio2face-not-launching-on-windows-11-because-of-python-asyncio-related-errors/262185
# /c/omniverse/apps/audio2face/404
# https://forums.developer.nvidia.com/u/jinqiu.peter
# https://forums.developer.nvidia.com/t/fbx-exports-dont-work-and-i-dont-understand-the-omniverse/262206
# /c/omniverse/general-discussion/329
# https://forums.developer.nvidia.com/tag/create
# https://forums.developer.nvidia.com/u/seanmchugh1
# https://forums.developer.nvidia.com/u/alan.james.kent
# https://forums.developer.nvidia.com/t/audio2face2023-1-0-to-ue-get-stuck/261780
# /c/omniverse/apps/audio2face/404
# https://forums.developer.nvidia.com/tag/audio2face
# https://forums.developer.nvidia.com/u/1757366814
# https://forums.developer.nvidia.com/u/Ehsan.HM
# https://forums.developer.nvidia.com/u/mp3rayne
# https://forums.developer.nvidia.com/u/Simplychenable
# https://forums.developer.nvidia.com/t/bboxcache-computation-is-wrong-during-pose-randomization/262190
# /c/omniverse/simulation/69
# https://forums.developer.nvidia.com/tag/python
# https://forums.developer.nvidia.com/u/christof.schuetzenhoefer
# https://forums.developer.nvidia.com/t/is-there-someone-from-nvidia-i-can-pay-to-walk-me-through-setting-up-a-cc-character/262189
# /c/omniverse/apps/audio2face/404
# https://forums.developer.nvidia.com/u/DataJuggler
# https://forums.developer.nvidia.com/t/unable-to-connect-to-nucleus-localhost/259928
# /c/omniverse/platform/nucleus/402
# https://forums.developer.nvidia.com/u/InfraredLaser
# https://forums.developer.nvidia.com/u/Ripeg
# https://forums.developer.nvidia.com/u/dlindsey
# https://forums.developer.nvidia.com/u/yujing.liu
# https://forums.developer.nvidia.com/u/DataJuggler
# https://forums.developer.nvidia.com/t/beginner-questions-of-audio2face-tool/262145
# /c/omniverse/apps/audio2face/404
# https://forums.developer.nvidia.com/u/formalemailptk
# https://forums.developer.nvidia.com/u/Simplychenable
# https://forums.developer.nvidia.com/t/desynchronization-issue-with-animated-blend-shapes-eyebrow-and-eyelash-animations-are-out-of-sync-with-the-facial-animation-in-maya/262045
# /c/omniverse/apps/audio2face/404
# https://forums.developer.nvidia.com/u/shaunjohnski
# https://forums.developer.nvidia.com/t/omniverse-launcher-news-doesnt-open-to-a-browser/262138
# /c/omniverse/apps/create/405
# https://forums.developer.nvidia.com/u/DataJuggler
# https://forums.developer.nvidia.com/u/Simplychenable
# https://forums.developer.nvidia.com/t/export-the-position-of-a-cylinder-as-a-python-variable/262128
# /c/omniverse/simulation/69
# https://forums.developer.nvidia.com/tag/robot-pose
# https://forums.developer.nvidia.com/tag/python
# https://forums.developer.nvidia.com/u/sy2154
# /c/omniverse/300?page=1
# /
# /categories
# /guidelines
# https://www.nvidia.com/en-us/about-nvidia/legal-info/
# https://www.nvidia.com/en-us/about-nvidia/privacy-policy/
# https://www.discourse.org
# https://www.nvidia.com/en-us/about-nvidia/legal-info/
# https://developer.nvidia.com/legal/terms
# https://www.nvidia.com/en-us/about-nvidia/privacy-policy/
# https://developer.nvidia.com/contact
# https://www.nvidia.com/en-us/about-nvidia/privacy-policy/

# %%
import time
from selenium import webdriver

# Remove the headless option to run the browser in non-headless mode
driver = webdriver.Chrome()

driver.get(url)

# Get the initial page height
prev_height = driver.execute_script("return Math.max( document.body.scrollHeight, document.body.offsetHeight, document.documentElement.clientHeight, document.documentElement.scrollHeight, document.documentElement.offsetHeight );")

# Scroll step by step and add a delay between each scroll to make it visible
scroll_step = 50 # Set the scroll step in pixels
while True:
    driver.execute_script("window.scrollTo(0, {});".format(prev_height + scroll_step))
    time.sleep(3)  # Add a delay of 0.5 seconds between each scroll to make it visible

    # Get the current page height after scrolling
    curr_height = driver.execute_script("return Math.max( document.body.scrollHeight, document.body.offsetHeight, document.documentElement.clientHeight, document.documentElement.scrollHeight, document.documentElement.offsetHeight );")

    # Check if we have reached the end of the page
    if curr_height == prev_height:
        break

    prev_height = curr_height  # Update the previous height for the next iteration

# Get the page source after scrolling
page_content = driver.page_source

# Close the WebDriver
driver.quit()


soup = BeautifulSoup(page_content, "html.parser")



forum_links = []

# Now you can extract the desired data from the soup object
# For example, to extract all the links on the page, you can use the following code
all_links = soup.find_all("a", href=True)
for link in all_links:
    forum_links.append(link['href'])

    if str(link['href']).startswith('https:'):
        forum_links.append(str(link['href']))
    elif str(link['href']).startswith('/t/'):
        forum_links.append(str(main_url)+str(link['href']))

# %%
forum_links = []


for link in all_links:
    
    
    
    if str(link['href']).startswith('https:'):
        forum_links.append(str(link['href']))
    elif str(link['href']).startswith('/t/'):
#         print(str(main_url) + str(link['href']))
        forum_links.append(str(main_url)+str(link['href']))

# %%
forum_links = list(set(forum_links))
forum_links
# Out:
# ['https://forums.developer.nvidia.com/t/is-it-possible-to-perform-cfd-computational-fluid-dynamics-simulations-using-omniverse-tools/258989',
#  'https://forums.developer.nvidia.com/t/how-to-edit-a-pivot-point-on-an-object/224020/5',
#  'https://forums.developer.nvidia.com/t/robot-reset-failing-if-in-contact-or-simultaneously-resetting-object-since-v2022-2-0/248452',
#  'https://forums.developer.nvidia.com/t/the-issue-pertains-to-a-memory-leak-that-arises-when-employing-the-delete-prim-and-create-prim-functions/257215/2',
#  'https://forums.developer.nvidia.com/t/memory-leak-with-omniisaacgymenv/260528/1',
#  'https://forums.developer.nvidia.com/t/sementic-type-on-face-in-a-mesh-prim/252850/3',
#  'https://forums.developer.nvidia.com/t/omniverse-kit-unit-tests-pass-but-set-fails/262047',
#  'https://forums.developer.nvidia.com/t/do-you-have-a-plan-to-also-convert-quilts-to-om-instead-of-only-solid-parts/228539',
#  'https://forums.developer.nvidia.com/t/cant-install-maya-legacy-connector-200-4/258266/8',
#  'https://forums.developer.nvidia.com/t/unreal-engine-speech-audio-to-audio2face/259045/2',
#  'https://forums.developer.nvidia.com/t/reinforcement-learning-example-jetracer-jetbot/196888/7',
#  'https://forums.developer.nvidia.com/t/usd-export-use-settings-for-render-crashes-create-22-3-3/246720',
#  'https://forums.developer.nvidia.com/t/unable-to-create-fire-flow/260254/3',
#  'https://forums.developer.nvidia.com/t/is-there-a-way-to-manage-prim-like-unitys-prefab-or-sketchups-component/260153/3',
#  'https://forums.developer.nvidia.com/t/weird-joint-effort-target-pos-and-vel-behavior/256955/2',
#  'https://forums.developer.nvidia.com/t/feature-request-for-omniclientliveprocess/261397/1',
#  'https://forums.developer.nvidia.com/u/pekka.varis',
#  'https://forums.developer.nvidia.com/t/not-able-to-sign-in-revit-omniverse-connector-file-transferring-failed/253776/3',
#  'https://forums.developer.nvidia.com/t/failed-to-execute-script-main/224073/4',
#  'https://forums.developer.nvidia.com/t/nvidia-folder-lock-in-the-local-host/260542',
#  'https://forums.developer.nvidia.com/t/omniverse-revit-connector-v202-0-2400/256565/2',
#  'https://forums.developer.nvidia.com/t/how-to-randomize-only-one-material-for-multiple-objects/245875',
#  'https://forums.developer.nvidia.com/t/problem-of-using-the-replicator-with-a-fully-developed-scene/256458/5',
#  'https://forums.developer.nvidia.com/t/isaac-sim-rendering-is-getting-slow-after-some-time/261643',
#  'https://forums.developer.nvidia.com/t/telecentric-lens-in-isaac-sim/232892',
#  'https://forums.developer.nvidia.com/t/issac-sim-people-simulation/257805',
#  'https://forums.developer.nvidia.com/t/bug-some-writer-rgb-images-are-blacked-out-when-generating-with-randomizer-instantiate/242934',
#  'https://forums.developer.nvidia.com/t/maya-arnold-error/233498',
#  'https://forums.developer.nvidia.com/t/compute-the-corners-for-an-array-of-prims-not-a-prim-in-omniverse-code-script-editor/246056/3',
#  'https://forums.developer.nvidia.com/t/cat-model-is-craching-my-blender-3-6/248414/11',
#  'https://forums.developer.nvidia.com/t/isaac-sim-lane-following-from-jetbot/255285/3',
#  'https://forums.developer.nvidia.com/t/abs-hard-leather-grey-turns-into-red-after-being-added-to-mesh/256623',
#  'https://forums.developer.nvidia.com/t/omniverse-connect-sample-updates/169966/15',
#  'https://forums.developer.nvidia.com/t/cant-assemble-uploading-1-gif/254843/7',
#  'https://forums.developer.nvidia.com/t/omnigraph-node-value-readout-using-python-code/259422/2',
#  'https://forums.developer.nvidia.com/t/issue-with-objects-with-link-from-iclone8-project/256352/3',
#  'https://forums.developer.nvidia.com/t/how-to-report-an-issue-with-omniverse/199675',
#  'https://forums.developer.nvidia.com/t/audio2face-lip-synch-not-working/257537',
#  'https://forums.developer.nvidia.com/t/quadruped-controller-in-the-example-cannot-move-backwards/255735/2',
#  'https://forums.developer.nvidia.com/t/removing-prims-between-frames/252844/7',
#  'https://forums.developer.nvidia.com/t/beginner-questions-of-audio2face-tool/262145',
#  'https://forums.developer.nvidia.com/t/reproduce-mouse-behaviour-from-scripts/256930/2',
#  'https://forums.developer.nvidia.com/t/how-to-unistall-nividia-omniverse-launcher/255530',
#  'https://forums.developer.nvidia.com/t/isaac-sim-omnigraph-python-api-make-array/255521/4',
#  'https://forums.developer.nvidia.com/t/no-correspondence-markers-bug/261880',
#  'https://forums.developer.nvidia.com/t/hi-how-can-i-create-a-new-user-in-nucleus-with-api-thanks-a-lot/250183',
#  'https://forums.developer.nvidia.com/t/how-to-listen-to-audio2face-livelink-server-in-python/262340/1',
#  'https://forums.developer.nvidia.com/t/is-it-possible-to-load-medical-imagiing-data-in-omniverse/213121',
#  'https://forums.developer.nvidia.com/t/can-omniverse-build-4d-progress-without-synchro-or-other-3rd-party-software/259816',
#  'https://forums.developer.nvidia.com/t/erro-while-runing-python-script-to-setup-action-graph/256879',
#  'https://forums.developer.nvidia.com/t/mcc-file-problems-for-maya/257407',
#  'https://forums.developer.nvidia.com/t/graphical-artifacts-and-errors-in-launcher-ui/258606/2',
#  'https://forums.developer.nvidia.com/t/saved-usd-after-adding-script-with-script-editor/260506',
#  'https://forums.developer.nvidia.com/t/isaac-sim-jupyter-notebook-instance-in-windows/255221',
#  'https://forums.developer.nvidia.com/t/integrate-husky-franka-robot-error/239716/8',
#  'https://forums.developer.nvidia.com/t/randomizer-gui/252945/6',
#  'https://forums.developer.nvidia.com/t/how-to-programmatically-select-a-prim-in-create/256757',
#  'https://forums.developer.nvidia.com/t/accesviolation-exception-while-saving-usd-stage-with-c-api/259996',
#  'https://forums.developer.nvidia.com/t/have-problem-getting-started/259801/4',
#  'https://forums.developer.nvidia.com/t/crash-during-train/230931/7',
#  'https://forums.developer.nvidia.com/t/cinema-4d-support/183786/26',
#  'https://forums.developer.nvidia.com/t/omni-machinima-warmup-bat/256615/1',
#  'https://forums.developer.nvidia.com/t/why-the-ros2-joint-space-subscriber-cannot-recieve-efforts/237561',
#  'https://forums.developer.nvidia.com/t/bug-report-articulations-with-cylinder-based-collisions-fall-through-default-ground-plane-in-isaac-sim-2022-2-1-gpu-physx/255971/1',
#  'https://forums.developer.nvidia.com/t/trouble-with-starting-reinforcement-learning-internal-index-error-suspected-due-to-an-articulationview/261307',
#  'https://forums.developer.nvidia.com/t/there-are-no-debug-kit-exe-in-the-extension-template-with-kit-105/261036/1',
#  'https://forums.developer.nvidia.com/t/error-while-using-rep-distribution-choice/254290/6',
#  'https://forums.developer.nvidia.com/t/loading-lights-into-isaac-sim/258914/4',
#  'https://forums.developer.nvidia.com/t/unable-to-install-blender-3-6-200-2-via-launcher-preexisting-blender-3-6-install/259228/1',
#  'https://forums.developer.nvidia.com/t/material-opacity/240570/2',
#  'https://forums.developer.nvidia.com/t/blender-3-6-0-alpha-v200-0-now-on-launcher/247198/3',
#  'https://forums.developer.nvidia.com/t/command-line-farm-submit/251611',
#  'https://forums.developer.nvidia.com/t/where-can-i-download-plugin-nvidia-omniverse-audio2face-livelink-could-not-find-it-in-unreal-plugin/260575',
#  'https://forums.developer.nvidia.com/t/ptx-loading/253756',
#  'https://forums.developer.nvidia.com/t/articulation-force-sensor-cant-get-contact-value/223141/10',
#  'https://forums.developer.nvidia.com/t/please-help-viewport-are-no-demo-model-show-up-after-open-audio2face/254654/4',
#  'https://forums.developer.nvidia.com/t/is-there-a-way-to-manage-prim-like-unitys-prefab-or-sketchups-component/260153',
#  'https://forums.developer.nvidia.com/t/streaming-xr/256535/1',
#  'https://forums.developer.nvidia.com/t/maya-2024-mayaomniverse-connector/251317',
#  'https://forums.developer.nvidia.com/t/exporting-marbles-sample-to-fbx-has-missing-textures/243851',
#  'https://forums.developer.nvidia.com/t/script-for-convex-decomposition-collisions/259649/2',
#  'https://forums.developer.nvidia.com/t/object-falling-during-manipulation/259725/3',
#  'https://forums.developer.nvidia.com/t/audio2face-2023-1-open-beta-released/259792',
#  'https://forums.developer.nvidia.com/t/could-not-find-ros-package-isaac-tutorials/260817',
#  'https://forums.developer.nvidia.com/t/how-to-use-stage-recorder-extension/257687/3',
#  'https://forums.developer.nvidia.com/u/seanmchugh1',
#  'https://forums.developer.nvidia.com/t/using-audio2face-in-offline-mod/254927',
#  'https://forums.developer.nvidia.com/t/the-script-of-randomizing-appearance-can-not-be-run/260176',
#  'https://forums.developer.nvidia.com/t/how-to-add-kinematics-and-dynamics-to-the-existing-robot-body/257191/2',
#  'https://forums.developer.nvidia.com/t/compiling-omniverse-compliant-ros2-custom-messages/258430',
#  'https://forums.developer.nvidia.com/t/is-the-documentation-for-isaac-sim-extensions-api-complete/256741/2',
#  'https://forums.developer.nvidia.com/t/how-to-add-kinematics-and-dynamics-to-the-existing-robot-body/257191',
#  'https://forums.developer.nvidia.com/t/pip-not-able-to-download-the-azureopenai-for-langchain-llms/259259/8',
#  'https://forums.developer.nvidia.com/t/can-not-modify-angular-damping-parameter-by-python-command/255740/4',
#  'https://forums.developer.nvidia.com/t/simulation-only-running-once/248125',
#  'https://forums.developer.nvidia.com/t/integrate-husky-franka-robot-error/239716',
#  'https://forums.developer.nvidia.com/t/linux-vs-windows-load-order-issue-kit104-no-module-named-omni-git-extension/257543',
#  'https://forums.developer.nvidia.com/t/export-usd-model-from-usd-composer-isaac-sim/258436/8',
#  'https://www.nvidia.com/en-us/events/siggraph/?nvid=nv-int-unbr-710451#cid=sigg23_nv-int-unbr_en-us',
#  'https://forums.developer.nvidia.com/t/view-is-failing-to-launch-on-a-linux/259911/1',
#  'https://forums.developer.nvidia.com/t/how-to-make-the-object-static-i-mean-it-shouldn-t-move-at-all-even-if-it-gets-hit/258094/3',
#  'https://forums.developer.nvidia.com/t/blender-3-6-0-alpha-v200-0-now-on-launcher/247198',
#  'https://forums.developer.nvidia.com/t/cant-export-blendshapes/240852',
#  'https://forums.developer.nvidia.com/t/get-camera-image-from-gym-in-headless-mode/245681',
#  'https://forums.developer.nvidia.com/t/could-not-load-the-qt-platform-plugin-xcb-in-cv2-qt-plugins-even-though-it-was-found/255259',
#  'https://forums.developer.nvidia.com/t/isaac-sim-2022-2-1-doesnt-start/255476',
#  'https://forums.developer.nvidia.com/t/isaac-sim-bookmarks-do-not-persist-after-container-restart/254891',
#  'https://forums.developer.nvidia.com/t/does-rtxgi-cutted-from-unreal-engine-5-2-nvidia-rtx-branch/261750',
#  'https://forums.developer.nvidia.com/u/agrant3d',
#  'https://forums.developer.nvidia.com/t/the-option-import-face-animation-is-not-present-in-ue5-ue-connectors-are-installed/260887',
#  'https://forums.developer.nvidia.com/t/modulenotfound-importing-python-kit-modules-into-connectorsample/260516',
#  'https://forums.developer.nvidia.com/t/is-machinina-the-right-tool-to-mock-up-a-stage-play/260737',
#  'https://forums.developer.nvidia.com/t/omniverse-launcher-news-doesnt-open-to-a-browser/262138',
#  'https://forums.developer.nvidia.com/t/cad-importer-and-the-importance-of-hierarchy/257494',
#  'https://forums.developer.nvidia.com/t/get-list-of-objects-in-a-scene/261400/2',
#  'https://forums.developer.nvidia.com/t/importing-rigged-character/259424/3',
#  'https://forums.developer.nvidia.com/tag/local-host',
#  'https://forums.developer.nvidia.com/t/isaac-sim-launch-stuck-after-rtx-ready/255917',
#  'https://forums.developer.nvidia.com/t/how-to-input-camera-feed-into-pose-tracker/258002',
#  'https://forums.developer.nvidia.com/t/instancing/256629',
#  'https://forums.developer.nvidia.com/t/maya-v-ray-workflow-connector/232292/3',
#  'https://forums.developer.nvidia.com/u/AlesBorovicka',
#  'https://forums.developer.nvidia.com/t/audio2face-2023-1-open-beta-released/259792/11',
#  'https://forums.developer.nvidia.com/t/scaling-problem-for-imported-usd-objects/260758/3',
#  'https://forums.developer.nvidia.com/t/import-omniverse-create-extension-but-got-permissionerror/243682',
#  'https://forums.developer.nvidia.com/t/api-integration/254811/2',
#  'https://forums.developer.nvidia.com/t/issac-sim-crusch-after-play/255025/4',
#  'https://forums.developer.nvidia.com/t/gas-flow-in-a-tube/256640/2',
#  'https://forums.developer.nvidia.com/t/semantics-schema-editor-visualization-using-point-instancers/262004/2',
#  'https://forums.developer.nvidia.com/t/reducing-dependencies-for-extensions-in-headless-kit-container/256591/4',
#  'https://forums.developer.nvidia.com/t/unitiliazed-robot-articulation-error-when-simulating-robot-and-clothing-in-the-same-scene/259574/2',
#  'https://forums.developer.nvidia.com/t/how-to-can-i-add-children-to-xform-while-simulating-using-python-standalone-workflow/261754/1',
#  'https://forums.developer.nvidia.com/t/how-to-display-timeline-on-isaac-sim-interface/258124/4',
#  'https://forums.developer.nvidia.com/t/reading-primvars-in-material/186112/10',
#  'https://forums.developer.nvidia.com/t/failed-to-upload-minidump-error-message-while-running-isaac-sim-from-docker/255949',
#  'https://forums.developer.nvidia.com/t/blendshape-solver-doesnt-apply-on-bs-mesh/260127',
#  'https://forums.developer.nvidia.com/t/get-camera-image-from-gym-in-headless-mode/245681/7',
#  'https://forums.developer.nvidia.com/t/is-there-a-blendshape-test-tool-for-usd-composer-feature-request-if-not/260426',
#  'https://forums.developer.nvidia.com/t/can-audio2face-headless-rest-api-be-used-for-commercial-use/257771/8',
#  'https://forums.developer.nvidia.com/t/can-i-now-import-alembic-data/256378',
#  'https://forums.developer.nvidia.com/t/support-for-3d-spacemouse-3dconnexion/193745',
#  'https://forums.developer.nvidia.com/t/viewport-not-responding-to-input-or-loading-meshes/259367',
#  'https://forums.developer.nvidia.com/t/audio2face-emotions-in-streaming-livelink-error/262343',
#  'https://forums.developer.nvidia.com/t/ros-navigation/254650/5',
#  'https://forums.developer.nvidia.com/t/calling-own-functions-between-2-frames-with-replicator/261087/1',
#  'https://forums.developer.nvidia.com/t/avoid-collisions-with-replicator/255880/6',
#  'https://forums.developer.nvidia.com/t/composer-not-booting-up-in-aws/254674',
#  'https://forums.developer.nvidia.com/t/isaac-sim-omnigraph-read-imu-node-index-out-of-bounds/241304/4',
#  'https://forums.developer.nvidia.com/t/lost-all-material-when-open-usd-files/186423/20',
#  'https://forums.developer.nvidia.com/t/missing-nodes-in-action-graph-when-i-reopen-the-usd-file-which-has-been-saved/261068/2',
#  'https://forums.developer.nvidia.com/t/character-transfer-issues/260403',
#  'https://forums.developer.nvidia.com/t/pip-libraries-in-usd-composer-not-installing/258642',
#  'https://forums.developer.nvidia.com/t/how-does-eye-compute-automatically-work-in-a2f/255628',
#  'https://forums.developer.nvidia.com/t/imu-topic-publish-code-error/247641/7',
#  'https://forums.developer.nvidia.com/t/problem-with-generated-bounding-boxes-in-omniverse-replicator/241116',
#  'https://forums.developer.nvidia.com/t/super-slow-execution-rtx-flow-plugin-failed/256680/1',
#  'https://forums.developer.nvidia.com/t/cannot-use-requests-py-module-in-my-extension-for-create/258350',
#  'https://forums.developer.nvidia.com/t/trouble-in-moveit2/262172',
#  'https://forums.developer.nvidia.com/t/cad-importer-missing-objects-other-issues/257498/2',
#  'https://forums.developer.nvidia.com/t/bookmarks/258463',
#  'https://forums.developer.nvidia.com/t/isaac-sim-steamvr-error/247510/4',
#  'https://forums.developer.nvidia.com/t/is-there-a-way-to-get-friction-forces/260730',
#  'https://forums.developer.nvidia.com/u/shaunjohnski',
#  'https://forums.developer.nvidia.com/t/create-uneven-terrain-on-isaac-sim/261640/2',
#  'https://forums.developer.nvidia.com/t/can-t-open-usd-file/258299',
#  'https://forums.developer.nvidia.com/t/camera-shake/259987',
#  'https://forums.developer.nvidia.com/t/unable-to-register-pose-annotator-with-replicator-and-omniverse-code/258325',
#  'https://forums.developer.nvidia.com/t/script-usdgeomxformable-placement-and-visibility-on-timeline/253353/5',
#  'https://forums.developer.nvidia.com/t/where-to-find-the-linux-version/256435/2',
#  'https://forums.developer.nvidia.com/t/how-to-query-sdf-for-cumtomized-shapes/262048',
#  'https://forums.developer.nvidia.com/t/i-cant-upload-my-usda-file-with-crawl-into-other-usda-file-or-python/259686',
#  'https://forums.developer.nvidia.com/t/wheel-robot-with-4-joints-cant-move-by-differential-controller-using-action-graph-and-ros/228800/15',
#  'https://forums.developer.nvidia.com/t/inconsistent-simulation-speeds-in-movie-capture-extension/260101/7',
#  'https://forums.developer.nvidia.com/t/lula-rrt-support-for-orientation-targets-and-mesh-collision-avoidance/250852/7',
#  'https://forums.developer.nvidia.com/t/many-holes-in-point-cloud-reconstruction-with-dmtet/257183/3',
#  'https://forums.developer.nvidia.com/t/livestream-3d-scene-composition-with-usd-composer-wed-may-31-11am-pst/254983/2',
#  'https://forums.developer.nvidia.com/t/how-to-get-distance-to-the-deformable-body/260295',
#  'https://forums.developer.nvidia.com/t/streaming-a2f-in-machinama/258355',
#  'https://forums.developer.nvidia.com/t/importing-extensions-into-nvidia-omniverse/256561',
#  'https://forums.developer.nvidia.com/t/audio2face-working-on-quadro-p5000/257398/4',
#  'https://forums.developer.nvidia.com/t/maya-connector-wont-install-for-thin-client-installations/241443/2',
#  'https://forums.developer.nvidia.com/t/turtlebot-joint-velocities-dont-match-the-desire-target-velocity/220383/8',
#  'https://forums.developer.nvidia.com/t/add-noise-to-the-camera-animation/259717',
#  'https://forums.developer.nvidia.com/t/advanced-skeleton-is-not-working-with-audio2face/258906/2',
#  'https://forums.developer.nvidia.com/t/not-able-to-open-any-nvidia-assets-on-the-omniverse-create-or-isaac-sim-apps/233313/4',
#  'https://forums.developer.nvidia.com/t/a-way-to-secure-the-source-of-the-extension/261561',
#  'https://forums.developer.nvidia.com/t/how-to-get-object-geometry-properties-in-a-scene/261322',
#  'https://forums.developer.nvidia.com/t/for-loop-with-orchestrator-in-replicator/241196/11',
#  'https://forums.developer.nvidia.com/t/luxurious-penthouse-archviz-animation/260065/1',
#  'https://forums.developer.nvidia.com/t/instance-segmentation-not-stable/259111/7',
#  'https://forums.developer.nvidia.com/t/have-problem-getting-started/259801',
#  'https://forums.developer.nvidia.com/t/replicator-interactive-sdg-fruit-box-tutorial-on-local-machine/258815/7',
#  'https://forums.developer.nvidia.com/t/what-music-interferes-with-instructors-audio-adam-moravansky-tutorial-physics-ext-kit-104/256170',
#  'https://forums.developer.nvidia.com/t/omni-anim-people/258811',
#  'https://forums.developer.nvidia.com/t/wrong-credentials-or-the-user-does-not-exist/256659',
#  'https://forums.developer.nvidia.com/t/omniverse-create-when-using-movie-capture-resource-usage-is-very-low/255614/2',
#  'https://forums.developer.nvidia.com/t/lots-of-isaac-sim-links-broken/259863/7',
#  'https://forums.developer.nvidia.com/t/how-to-assign-texture-map-to-material-in-python/258551/2',
#  'https://developer.nvidia.com/',
#  'https://forums.developer.nvidia.com/t/blender-3-6-exchange-version-to-omniverse-to-unreal-engine-5-2-with-nucleus-localhost-does-not-seem-efficient/255891',
#  'https://forums.developer.nvidia.com/t/cannot-delete-the-folders-from-nucleus/220627',
#  'https://forums.developer.nvidia.com/t/i-can-not-found-the-unreal-plugin/259834/5',
#  'https://forums.developer.nvidia.com/t/isaac-sim-documentation-404/259882',
#  'https://forums.developer.nvidia.com/t/unable-to-install-blender-3-6-200-2-via-launcher-preexisting-blender-3-6-install/259228',
#  'https://forums.developer.nvidia.com/t/running-replicator-headless-never-runs/257918',
#  'https://forums.developer.nvidia.com/t/graphical-artifacts-and-errors-in-launcher-ui/258606',
#  'https://forums.developer.nvidia.com/t/nucleus-server-doesnot-have-any-services/262284',
#  'https://forums.developer.nvidia.com/t/usd-asset-for-deformable-cable-rope/261265',
#  'https://forums.developer.nvidia.com/t/openning-anonymous-layers/256810',
#  'https://forums.developer.nvidia.com/t/omniverse-code-crashes-while-running-script/254798',
#  'https://forums.developer.nvidia.com/t/our-guide-to-nvidia-omniverse-at-siggraph-2023/261409',
#  'https://forums.developer.nvidia.com/t/omniverse-houdini-connector-docker-errors/258802',
#  'https://forums.developer.nvidia.com/t/omniverse-create-material-loading-issue/257151',
#  'https://forums.developer.nvidia.com/t/more-powerful-ease-in-controls-for-keyframes-please/257482',
#  'https://forums.developer.nvidia.com/t/how-to-get-the-camera-data-for-centerpose-model-training/259371',
#  'https://forums.developer.nvidia.com/t/mark-solved-arkit-audio2face-2023-1-0-is-not-working/261116/4',
#  'https://forums.developer.nvidia.com/t/isaac-sim-2022-2-1-stuck-opening-hello-world-or-any-usd-saved-file/259210',
#  'https://forums.developer.nvidia.com/t/please-someone-help-its-the-first-time-im-using-usd-and-it-is-already-not-loading-in-my-maya-2022/258889/6',
#  'https://forums.developer.nvidia.com/t/extension-processing-currently-opened-stage/260215/1',
#  'https://forums.developer.nvidia.com/t/how-to-insert-camera-intrinsic-matrix-and-distortion-coefficients-for-the-camera-other-than-fisheyepolynomial/252014/9',
#  'https://forums.developer.nvidia.com/t/rendered-image-not-visible-camera-sensor-standalone-python-example/255585',
#  'https://forums.developer.nvidia.com/t/cant-install-maya-legacy-connector-200-4/258266',
#  'https://forums.developer.nvidia.com/t/code-crashes-after-running-replicator/250362',
#  'https://forums.developer.nvidia.com/t/question-on-using-surface-gripper-by-ros-in-isaac-sim/204746',
#  'https://forums.developer.nvidia.com/t/cant-load-omni-physx-when-running-create/254790',
#  'https://forums.developer.nvidia.com/t/ferret-example-where/259913/3',
#  'https://forums.developer.nvidia.com/t/how-to-switch-from-one-environment-stage-to-another-using-action-graph/254911',
#  'https://forums.developer.nvidia.com/t/what-is-the-correct-way-to-build-a-simulated-rope/244881/10',
#  'https://forums.developer.nvidia.com/t/update-displacement-maps/258473',
#  'https://forums.developer.nvidia.com/t/how-to-get-torque-values-of-robot-joints-with-rmpflow-motion-policy-in-frankas-pick-and-place-task/257149/6',
#  'https://forums.developer.nvidia.com/t/unable-to-register-pose-annotator-with-replicator-and-omniverse-code/258325/2',
#  'https://forums.developer.nvidia.com/t/couple-issues-ive-not-found-a-solution-to-gizmo-local-fwd/261879/8',
#  'https://forums.developer.nvidia.com/t/what-is-the-correct-way-to-build-a-simulated-rope/244881',
#  'https://forums.developer.nvidia.com/t/crashed-when-saving-in-omniverse-setting-in-revit/259682',
#  'https://forums.developer.nvidia.com/t/composer-2023-1-1-error-omni-usd-has-no-attribute-utils/261636',
#  'https://forums.developer.nvidia.com/u/ayushsahai0074',
#  'https://forums.developer.nvidia.com/t/omniverse-create-material-loading-issue/257151/1',
#  'https://forums.developer.nvidia.com/t/the-image-of-the-self-made-camera-becomes-the-image-of-the-perspective-camera/260182/5',
#  'https://forums.developer.nvidia.com/t/isaac-sim-crashes-when-loading-a-demo-scene-windows-11/261359',
#  'https://forums.developer.nvidia.com/t/where-is-the-domain-randomizer-dr/260188',
#  'https://forums.developer.nvidia.com/t/about-issacgym/260580/2',
#  'https://forums.developer.nvidia.com/t/movie-capture-extension-not-available-in-audio2face-in-version-2022-2-1/255356',
#  'https://forums.developer.nvidia.com/t/stack-trace-trying-to-add-cloth-mesh-to-hair/256578',
#  'https://forums.developer.nvidia.com/t/how-to-keyframe-the-properties-of-multiple-lights/259769',
#  'https://forums.developer.nvidia.com/t/composer-installation-error/258586/12',
#  'https://forums.developer.nvidia.com/t/contact-reporter-between-deformable-and-rigid-bodies/259884',
#  'https://forums.developer.nvidia.com/t/isaac-sim-could-not-be-launched/256443/3',
#  'https://forums.developer.nvidia.com/t/gas-flow-in-a-tube/256640',
#  'https://forums.developer.nvidia.com/t/randomizer-based-replicator-code-gets-slower-every-frame/252002',
#  'https://forums.developer.nvidia.com/t/webrtc-on-omniverse-apps-does-not-stream-audio-output-to-browser/209037',
#  'https://forums.developer.nvidia.com/t/read-value-from-omnigraph-node/256525/4',
#  'https://forums.developer.nvidia.com/t/replicator-composer-rtx-lidar-sensor/253775',
#  'https://forums.developer.nvidia.com/t/extensions-are-not-loading/259220/5',
#  'https://forums.developer.nvidia.com/t/adding-2d-image-as-texture-to-a-height-field/261041/5',
#  'https://forums.developer.nvidia.com/t/is-there-a-built-in-torque-sensor/183900/6',
#  'https://forums.developer.nvidia.com/t/usd-plug-in-not-loading-up-in-maya-2022-23/258891/3',
#  'https://forums.developer.nvidia.com/t/object-is-not-rendered-when-dragged-in-through-the-content-browser-but-is-ok-when-added-as-a-layer/258765/6',
#  'https://forums.developer.nvidia.com/t/trigger-randomization/254170',
#  'https://forums.developer.nvidia.com/t/composer-crashes-with-renderfarm-4x-a4000-24c-32g/257150',
#  'https://forums.developer.nvidia.com/t/grid-geometry-keeps-reappearing/260819/4',
#  'https://forums.developer.nvidia.com/t/abs-hard-leather-grey-turns-into-red-after-being-added-to-mesh/256623/4',
#  'https://forums.developer.nvidia.com/t/does-orbit-support-domain-randomization/252079/4',
#  'https://forums.developer.nvidia.com/t/general-omniverse-apps-launching-problem/255866',
#  'https://forums.developer.nvidia.com/t/instance-segmentation-with-pointcloud-generation/259248/4',
#  'https://forums.developer.nvidia.com/t/any-policy-on-loading-py-modules-with-dll-in-dependencies/261580',
#  'https://forums.developer.nvidia.com/t/isaac-sim-crashing-while-launching-ros-navigation-example/261394/4',
#  'https://forums.developer.nvidia.com/t/custom-omnigraph-ros-publisher-node/258208/4',
#  'https://forums.developer.nvidia.com/t/siggraph-sizzle-reel-opportunity/254982/2',
#  'https://forums.developer.nvidia.com/t/kit-105-how-to-get-early-access/258936',
#  'https://forums.developer.nvidia.com/t/error-installing-composer-2023-1-0/258408/6',
#  'https://forums.developer.nvidia.com/t/can-not-turn-on-live-in-tutorial-using-jupyter/256258',
#  'https://forums.developer.nvidia.com/t/wrong-mtethod-signature-in-physicsutils/255067',
#  'https://forums.developer.nvidia.com/t/question-on-using-surface-gripper-by-ros-in-isaac-sim/204746/5',
#  'https://forums.developer.nvidia.com/t/how-to-display-data-from-a-csv-file-in-a-usd-file-on-an-object/258623',
#  'https://forums.developer.nvidia.com/t/what-is-this-little-blue-marker/262067',
#  'https://developer.nvidia.com',
#  'https://forums.developer.nvidia.com/t/possible-memory-leak-in-kit/260508',
#  'https://forums.developer.nvidia.com/t/isaac-sim-crashes-when-loading-a-demo-scene-windows-11/261359/2',
#  'https://forums.developer.nvidia.com/t/in-z-up-usd-save-select-prim-to-new-usd-the-geometry-gets-flipped-like-y-up/259757',
#  'https://forums.developer.nvidia.com/t/usd-composer-2023-11-beta-now-available-hot-fix-for-people-with-installation-issues/259618/13',
#  'https://forums.developer.nvidia.com/t/from-omniverse-to-sketchfab/202739/6',
#  'https://forums.developer.nvidia.com/t/nvidia-assets-samples-environments-etc-are-not-loading/254014',
#  'https://forums.developer.nvidia.com/t/lagging-in-ue5-2-when-connector-plugin-is-active/260642',
#  'https://forums.developer.nvidia.com/t/audio2face-unreal-export-custom-metahuman-head-from-unreal-with-blendshapes-for-blendshape-solve/256567/2',
#  'https://forums.developer.nvidia.com/t/question-about-orbit-rl-environment/257279',
#  'https://forums.developer.nvidia.com/t/alembic-file-imports-look-different-that-native-mesh-with-same-materal/256608/3',
#  'https://forums.developer.nvidia.com/t/where-do-the-content-packs-install-to/218307',
#  'https://forums.developer.nvidia.com/t/how-to-edit-the-example-scenarios-in-issac-sim/256080/2',
#  'https://forums.developer.nvidia.com/t/with-4-vdb-s-composer-is-still-crashing-quite-a-lot/262232/1',
#  'https://forums.developer.nvidia.com/t/isaac-sim-crashed-on-launch-isaac-sim-2022-2-1-and-isaac-sim-2022-2-0/260728/4',
#  'https://forums.developer.nvidia.com/t/my-computer-is-in-the-shop-will-omniverse-run-on-a-1080ti/258480',
#  'https://forums.developer.nvidia.com/t/issac-sim-launch-issue-using-omniverse/260251',
#  'https://forums.developer.nvidia.com/t/omniverse-vscode-dubug-configuration/215261',
#  'https://forums.developer.nvidia.com/t/exporting-skinned-objects/255273/3',
#  'https://forums.developer.nvidia.com/t/omniverse-xr-blurry-vr-scene/234809',
#  'https://forums.developer.nvidia.com/t/error-on-nucleus-stack-ssl-yml/256022/2',
#  'https://forums.developer.nvidia.com/t/stream-audio2face-blendshapes-between-two-computers/261371',
#  'https://forums.developer.nvidia.com/t/how-to-programmatically-select-a-prim-in-create/256757/3',
#  'https://forums.developer.nvidia.com/t/build-an-avatar-with-asr-chatgpt-tts-and-omniverse-audio2face/261829',
#  'https://forums.developer.nvidia.com/u/claudius.rimmele',
#  'https://forums.developer.nvidia.com/t/custom-omnigraph-ros-publisher-node/258208',
#  'https://forums.developer.nvidia.com/t/the-option-import-face-animation-is-not-present-in-ue5-ue-connectors-are-installed/260887/5',
#  'https://forums.developer.nvidia.com/t/audio2face-saas/179663/24',
#  'https://forums.developer.nvidia.com/t/color-each-side-of-the-cubeg/260266/4',
#  'https://forums.developer.nvidia.com/t/please-help-create-is-crashing-my-whole-computer/252264',
#  'https://forums.developer.nvidia.com/t/a-quick-question-about-the-omnigraph-draw-screen-space-text/258556',
#  'https://forums.developer.nvidia.com/t/how-to-build-a-python-app-from-connect-sample/259047/2',
#  'https://forums.developer.nvidia.com/t/composer-not-booting-up-in-aws/254674/3',
#  'https://forums.developer.nvidia.com/t/problem-for-contact-sensor/260089/3',
#  'https://forums.developer.nvidia.com/t/how-to-use-randomizer-tool-on-surface-instancer/257163',
#  'https://forums.developer.nvidia.com/t/cannot-find-modulus-extensions-in-create-2022-3-3/251412',
#  'https://forums.developer.nvidia.com/t/exception-failed-to-get-dof-stiffnesses-from-backend-fixedjoints-only-robots-not-allowed-to-create-articulation-view/240741/8',
#  'https://forums.developer.nvidia.com/t/feature-request-thumbnails-for-various-texture-img-files-in-content-browser/254802',
#  'https://forums.developer.nvidia.com/t/please-someone-help-its-the-first-time-im-using-usd-and-it-is-already-not-loading-in-my-maya-2022/258889',
#  'https://forums.developer.nvidia.com/t/have-anyone-had-success-with-mecanum-wheels-on-isaac/220820/15',
#  'https://forums.developer.nvidia.com/t/isaac-sim-omnigraph-python-api-make-array/255521',
#  'https://forums.developer.nvidia.com/t/a-problem-when-using-audio2face-rest-api/256090',
#  'https://forums.developer.nvidia.com/u/tsosnoski',
#  'https://forums.developer.nvidia.com/t/setting-different-colors-to-each-side-of-a-plane/261295/1',
#  'https://forums.developer.nvidia.com/tag/slam',
#  'https://forums.developer.nvidia.com/t/kit-app-play-physics/261835',
#  'https://forums.developer.nvidia.com/t/issues-with-using-omniverse-with-unreal-engine-5/255635',
#  'https://forums.developer.nvidia.com/t/isnt-there-an-extension-called-flatcache/261022',
#  'https://forums.developer.nvidia.com/t/focus-on-a-node-in-mdl-graph-editor/254675/3',
#  'https://forums.developer.nvidia.com/t/fisheye-lens-parameters-modification/254255',
#  'https://forums.developer.nvidia.com/t/object-is-not-rendered-when-dragged-in-through-the-content-browser-but-is-ok-when-added-as-a-layer/258765',
#  'https://forums.developer.nvidia.com/t/incorrect-forces-are-returned-by-rigidprimview-get-net-contact-forces/260686',
#  'https://forums.developer.nvidia.com/t/houdini-omniverse-connector-v102-3-release-error/243791/16',
#  'https://forums.developer.nvidia.com/t/is-there-any-progress-or-plans-to-enable-font-sizes-in-code-or-composer/260239/1',
#  'https://forums.developer.nvidia.com/t/problem-when-import-deformable-object-collision-mesh/257603/2',
#  'https://forums.developer.nvidia.com/t/audio2face-saas/179663',
#  'https://forums.developer.nvidia.com/t/trouble-with-adding-contact-sensors-to-robot/261317/3',
#  'https://forums.developer.nvidia.com/t/cant-retrieve-skeleton-data-with-synthetic-data-recorder/256053',
#  'https://forums.developer.nvidia.com/t/failed-to-execute-script-main/224073',
#  'https://forums.developer.nvidia.com/t/waiting-for-compilation-of-ray-tracing-shaders-by-gpu-driver-on-ubuntu-22-04/256811',
#  'https://forums.developer.nvidia.com/t/viewport-not-responding-to-input-or-loading-meshes/259367/6',
#  'https://forums.developer.nvidia.com/t/omniverse-code-close-itself-and-crash-many-times/260279/1',
#  'https://forums.developer.nvidia.com/t/audio2face-and-animation-graph-integration/259032/3',
#  'https://forums.developer.nvidia.com/t/nvidia-assets-samples-environments-etc-are-not-loading/254014/15',
#  'https://forums.developer.nvidia.com/t/why-cant-the-lidar-detect-deformable-body/261538/3',
#  'https://forums.developer.nvidia.com/t/problem-for-contact-sensor/260089',
#  'https://forums.developer.nvidia.com/t/mysterious-nucleus-installation-problem-no-localhost-cloud-under-omniverse-after-installation/260770',
#  'https://forums.developer.nvidia.com/t/creating-randomized-perlin-texture/257313',
#  'https://forums.developer.nvidia.com/t/how-to-fix-retargeting-issues-in-audio2gesture-machinima/255630',
#  'https://forums.developer.nvidia.com/t/omniverse-launcher-stuck-at-login-in-ubuntu/261635/4',
#  'https://forums.developer.nvidia.com/t/how-to-handle-material-assignment-on-geomsubsets/258427/8',
#  'https://forums.developer.nvidia.com/t/kit-105-and-particle-cloth-for-hair-physics-various-strange-behavior/259004',
#  'https://forums.developer.nvidia.com/t/material-opacity/240570',
#  'https://forums.developer.nvidia.com/t/composer-2023-1-errors-on-startup/259215',
#  'https://forums.developer.nvidia.com/t/error-when-importing-a-robot-from-usd-in-python-scripting/256725',
#  'https://forums.developer.nvidia.com/t/basic-tutorials-on-coding-content-creation/253925/6',
#  'https://forums.developer.nvidia.com/t/urgent-help-please-doexecute-error-always-appears/256946/4',
#  'https://forums.developer.nvidia.com/t/super-slow-execution-rtx-flow-plugin-failed/256680',
#  'https://forums.developer.nvidia.com/t/launcher-cannot-log-in/259871/5',
#  'https://forums.developer.nvidia.com/t/audio2face-stuck-on-loading-tensorrt-engine/255771',
#  'https://forums.developer.nvidia.com/t/skeleton-bones-in-viewport-not-showing-in-105/258643',
#  'https://forums.developer.nvidia.com/t/ros2-humble-requesting-update-on-source-code-for-7-multiple-robot-ros2-navigation-tutorial-that-is-compatible-with-ros2-humble/255166',
#  'https://forums.developer.nvidia.com/t/rigidprimview-reg-exp-path-error/254653',
#  'https://forums.developer.nvidia.com/t/i-can-not-found-the-unreal-plugin/259834',
#  'https://forums.developer.nvidia.com/t/memory-corruption-when-trying-to-create-blend-shapes-and-skeleton-animation-prims/260742',
#  'https://forums.developer.nvidia.com/t/inconsistent-simulation-speeds-in-movie-capture-extension/260101',
#  'https://forums.developer.nvidia.com/t/isaac-sim-moveit-motion-planning-framework-franka/232098',
#  'https://forums.developer.nvidia.com/t/audio2face-headless-mode-error-when-export-blendshape/259793/2',
#  'https://forums.developer.nvidia.com/t/where-is-nvidia-omniverse-audio2face-livelink-plugin/260003/3',
#  'https://forums.developer.nvidia.com/t/create-uneven-terrain-on-isaac-sim/261640',
#  'https://forums.developer.nvidia.com/t/omni-anim-people-issue-with-frame-rate-when-capturing-movie/241259',
#  'https://forums.developer.nvidia.com/t/visualize-a-simple-voxelgrid/256093',
#  'https://forums.developer.nvidia.com/t/robotiq-problem/252948',
#  'https://forums.developer.nvidia.com/t/the-protocal-of-streaming/261748',
#  'https://forums.developer.nvidia.com/t/using-waveworks-2-0-with-omniverse/241317',
#  'https://forums.developer.nvidia.com/t/face-indices-returned-by-getfacevertexindicesattr-incomplete-warp-usdgeom/254206',
#  'https://forums.developer.nvidia.com/t/our-guide-to-nvidia-omniverse-at-siggraph-2023/261409/1',
#  'https://forums.developer.nvidia.com/t/cant-receive-image-from-isaac-sim-docker-image-using-ros2-humble/257877',
#  'https://forums.developer.nvidia.com/t/sclect-xform-case-robot-move-when-importing-urdf/259675',
#  'https://forums.developer.nvidia.com/t/ptx-loading/253756/2',
#  'https://forums.developer.nvidia.com/t/camera-info-in-ros-topic-after-changing-the-height-and-width-have-large-difference-in-fx-and-fy-why-does-this-happen/255819/2',
#  'https://forums.developer.nvidia.com/t/scaled-objects-do-not-change-physical-properties/258575',
#  'https://forums.developer.nvidia.com/t/issac-sim-installation-error-related-to-pip-versionu/258677/2',
#  'https://forums.developer.nvidia.com/t/how-to-get-object-geometry-properties-in-a-scene/261322/2',
#  'https://forums.developer.nvidia.com/t/usd-composer-xr-vr-experiencing-really-poor-quality-in-vr/261866/1',
#  'https://forums.developer.nvidia.com/t/sim2real-of-rmpflowcontrol-on-my-robot/203876/6',
#  'https://forums.developer.nvidia.com/t/failed-to-login-stuck-after-logging-in-web-browser/260298/13',
#  'https://forums.developer.nvidia.com/t/public-audio2face-python-api-for-audio-animation/258340',
#  'https://forums.developer.nvidia.com/u/rodolphe.assere',
#  'https://forums.developer.nvidia.com/t/force-units-for-angular-and-linear-drive/254143/7',
#  'https://forums.developer.nvidia.com/t/audio2face-lip-synch-not-working/257537/4',
#  'https://forums.developer.nvidia.com/t/add-search-path-for-lidar-configs/255352/7',
#  'https://forums.developer.nvidia.com/t/set-exact-intrinsic-matrix-of-camera-fails/257491',
#  'https://forums.developer.nvidia.com/t/fail-to-load-built-in-material/236554',
#  'https://forums.developer.nvidia.com/t/rtx-loading-message-on-the-viewport/261440/3',
#  'https://forums.developer.nvidia.com/t/fail-to-launch-nvblox-with-isaac-sim/255814',
#  'https://forums.developer.nvidia.com/t/omni-anim-people-lidar/253142/8',
#  'https://forums.developer.nvidia.com/t/cant-load-physx-on-integrated-gpu-with-version-2023-1-0/258414/6',
#  'https://forums.developer.nvidia.com/t/isaac-sim-ros2-dependencies/256092',
#  'https://forums.developer.nvidia.com/t/launcher-cannot-log-in/259871',
#  'https://forums.developer.nvidia.com/t/omniverse-create-and-isaac-sim-fail-to-launch-in-linux/255023',
#  'https://forums.developer.nvidia.com/t/cannot-load-hello-world/256415',
#  'https://forums.developer.nvidia.com/t/ghosting-previous-objects-shapes-on-new-render/213399',
#  'https://forums.developer.nvidia.com/t/isaac-sim-imu-not-yielding-correct-measurements-when-changing-its-orientation/250837/8',
#  'https://forums.developer.nvidia.com/t/is-there-a-simpler-example-on-how-rl-environment-works-in-isaac-sim-and-gym/256300/6',
#  'https://forums.developer.nvidia.com/t/need-viewports-in-standalone-windows-but-built-in-operation-crashes-isaac-sim/254456',
#  'https://forums.developer.nvidia.com/t/how-to-generate-objects-binary-masks-for-synthetic-data-offline-pose-generation/258024/5',
#  'https://forums.developer.nvidia.com/t/kit-105-and-particle-cloth-for-hair-physics-various-strange-behavior/259004/1',
#  'https://forums.developer.nvidia.com/t/cloth-simulation-parameters/255130',
#  'https://forums.developer.nvidia.com/t/omniverse-code-crashes-while-running-script/254798/4',
#  'https://forums.developer.nvidia.com/t/im-looking-for-photo-realistic-articulated-objects-assets/259443/5',
#  'https://forums.developer.nvidia.com/t/isaac-sim-install-issue-buildpipeline-and-shader-loading-failed/250536/15',
#  'https://forums.developer.nvidia.com/t/unable-to-install-omniverse-launcher-failed-to-get-documents-path/243786',
#  'https://forums.developer.nvidia.com/t/generating-synthetic-data-with-preset-animation/259026',
#  'https://forums.developer.nvidia.com/t/3dsmax-2023-exporting-models-with-instances-and-broken-shaders/233673',
#  'https://forums.developer.nvidia.com/t/is-there-any-progress-or-plans-to-enable-font-sizes-in-code-or-composer/260239',
#  'https://forums.developer.nvidia.com/t/trajectory-generator-for-franka-panda-arm-not-working/259734/2',
#  'https://forums.developer.nvidia.com/t/maya-connector-wont-install-for-thin-client-installations/241443',
#  'https://forums.developer.nvidia.com/t/how-to-edit-a-pivot-point-on-an-object/224020',
#  'https://forums.developer.nvidia.com/t/can-we-create-game-using-omniverse-apps-and-publish-them-to-playstation/254907',
#  'https://forums.developer.nvidia.com/t/orientation-of-camera/260757/2',
#  'https://forums.developer.nvidia.com/t/grasshopper-mdl-table/257273',
#  'https://forums.developer.nvidia.com/t/docker-issue/259802',
#  'https://forums.developer.nvidia.com/t/replicator-sometimes-seems-to-break-the-existing-camera/253003',
#  'https://forums.developer.nvidia.com/t/water-materials-black-spots-how-to-eliminate/256500/6',
#  'https://forums.developer.nvidia.com/t/script-editor-not-loading-the-code-from-jupyter-lab/257275/2',
#  'https://forums.developer.nvidia.com/t/compute-the-corners-for-an-array-of-prims-not-a-prim-in-omniverse-code-script-editor/246056',
#  'https://forums.developer.nvidia.com/t/can-intel-i5-12400f-install-isaac-sim/255692/5',
#  'https://forums.developer.nvidia.com/t/crashed-when-saving-in-omniverse-setting-in-revit/259682/2',
#  'https://forums.developer.nvidia.com/t/objects-on-the-cloned-environments-copy-the-transformations-of-the-objects-in-the-base-environment/260337',
#  'https://forums.developer.nvidia.com/t/cant-load-custom-assets-into-isaac-sim/229230/20',
#  'https://forums.developer.nvidia.com/t/how-can-i-handle-images-at-headless-mode/254427',
#  'https://forums.developer.nvidia.com/t/point-cloud-transformation-error-from-depth-map/259217',
#  'https://forums.developer.nvidia.com/t/ros2-camera-infos-distortion-model-is-invalid/232429',
#  'https://forums.developer.nvidia.com/t/omnigraph-node-value-readout-using-python-code/259422',
#  'https://forums.developer.nvidia.com/t/orthographic-camera-still-bugged/255331/5',
#  'https://forums.developer.nvidia.com/t/closed-chain-robot-in-isaac-sim/217070',
#  'https://forums.developer.nvidia.com/t/isaac-sim-crashes-when-try-load/256282/2',
#  'https://forums.developer.nvidia.com/t/omniverse-create-installation-failed/221008/5',
#  'https://forums.developer.nvidia.com/t/omniverse-launcher-can-not-open/259035',
#  'https://forums.developer.nvidia.com/t/omniverse-audio2face-doesnt-load-the-face-mesh-please-help/197154',
#  'https://forums.developer.nvidia.com/t/omniverse-launcher-can-not-open/259035/4',
#  'https://forums.developer.nvidia.com/t/audio2face-stand-alone-application-deployment/254861',
#  'https://forums.developer.nvidia.com/t/i-created-a-server-i-think-but-i-dont-know-my-server-name/261882/1',
#  'https://forums.developer.nvidia.com/t/omniverse-code-extension-spawn-prim-with-non-standard-height-width-and-depth/259137/4',
#  'https://forums.developer.nvidia.com/t/moveit2-cannot-build-ros2-humble-ubuntu-22-04/254152',
#  'https://forums.developer.nvidia.com/t/omniverse-audio2face/259099',
#  'https://forums.developer.nvidia.com/t/isaac-sim-crashes-when-try-load/256282',
#  'https://forums.developer.nvidia.com/t/root-motion-for-characters-in-sequencer/253247',
#  'https://forums.developer.nvidia.com/t/objects-on-the-cloned-environments-copy-the-transformations-of-the-objects-in-the-base-environment/260337/8',
#  'https://forums.developer.nvidia.com/t/gpu-load-from-new-kit-process-even-without-stage-and-active-eco-mode/254159',
#  'https://forums.developer.nvidia.com/t/issac-sim-python-api-camera-orientation-ignored/241296/16',
#  'https://forums.developer.nvidia.com/t/omniverse-connector-for-siemens-plant-simulation-and-process-simulate/241952',
#  'https://forums.developer.nvidia.com/t/problem-mesh-fitting-audio2face-points-attachment-to-the-mesh/256271',
#  'https://forums.developer.nvidia.com/t/why-the-ros2-joint-space-subscriber-cannot-recieve-efforts/237561/4',
#  'https://forums.developer.nvidia.com/t/realsense2-description-no-definition-of-xacro-for-os-version-focal/254767/8',
#  'https://forums.developer.nvidia.com/t/creating-and-destroying-prims-during-runtime-in-isaac-sim/260876',
#  'https://forums.developer.nvidia.com/t/audio2face-stand-alone-application-deployment/254861/5',
#  'https://forums.developer.nvidia.com/t/how-to-write-raw-usd-property-each-frame/251990/4',
#  'https://forums.developer.nvidia.com/t/warning-while-calling-function-with-self-world-step-render-self-render-in-the-control-frequency-inv-loop/257424/3',
#  'https://forums.developer.nvidia.com/t/how-can-i-create-the-expanded-collapsed-ui-with-action-graph/256864/1',
#  'https://forums.developer.nvidia.com/t/substance-painter-9-support/259300/3',
#  'https://forums.developer.nvidia.com/t/streaming-xr/256535',
#  'https://forums.developer.nvidia.com/t/reading-primvars-in-material/186112',
#  'https://forums.developer.nvidia.com/t/get-object-center-pose-in-camera-frame-viewport/255358',
#  'https://forums.developer.nvidia.com/t/how-to-increase-rmp-lula-performance-on-a-custom-6d-robot/257190',
#  'https://forums.developer.nvidia.com/t/how-to-implement-the-functionality-automation-process-of-audio2gesture/260500/1',
#  'https://forums.developer.nvidia.com/t/unitiliazed-robot-articulation-error-when-simulating-robot-and-clothing-in-the-same-scene/259574',
#  'https://forums.developer.nvidia.com/t/isaac-sim-ros2-humble-using-cyclonedds/255079/3',
#  'https://forums.developer.nvidia.com/t/houdini-omniverse-connector-v102-3-release-error/243791',
#  'https://forums.developer.nvidia.com/t/moveit2-and-omniverse-isaac-sim-connection-is-not-working-demo-isaac/262057',
#  'https://forums.developer.nvidia.com/t/unexpected-robot-movement-in-environment-with-sdf-based-collision-and-fixed-joints/259703',
#  'https://forums.developer.nvidia.com/t/how-to-use-code-to-move-anim-people-one-step/262080/1',
#  'https://forums.developer.nvidia.com/t/deepsearch-not-displaying-in-navigator-after-extension-enabled/246595',
#  'https://forums.developer.nvidia.com/t/reporting-position-of-objects-on-conveyor/261420/3',
#  'https://forums.developer.nvidia.com/t/enable-ros-brdige-via-pyhton-script/257793/2',
#  'https://forums.developer.nvidia.com/t/isaac-sim-full-screen-mode/257639',
#  'https://forums.developer.nvidia.com/t/physics-simulation-in-replicator-docker-ovx-strange-results/251527',
#  'https://forums.developer.nvidia.com/t/carter-v2-urdf-mesh/258492',
#  'https://forums.developer.nvidia.com/t/how-to-fuse-basicwriter-semantic-standard-classes-unlabelled-and-background-to-one-class/248711',
#  'https://forums.developer.nvidia.com/t/how-to-set-defaultprim-in-api/246779',
#  'https://forums.developer.nvidia.com/t/omniverse-audio2face/259101/3',
#  'https://forums.developer.nvidia.com/t/omniverse-launcher-login-problem-on-linux-kubuntu-20-04/260409',
#  'https://forums.developer.nvidia.com/t/moveit2-cannot-build-ros2-humble-ubuntu-22-04/254152/14',
#  'https://forums.developer.nvidia.com/t/nucleus-hell/260655',
#  'https://forums.developer.nvidia.com/t/may-i-use-the-audio2face-with-command-line/255329/6',
#  'https://forums.developer.nvidia.com/t/unable-to-log-to-nucleus-server-through-code/255951',
#  'https://forums.developer.nvidia.com/t/bug-report-instances-batch-exported-as-references-payloads-explode-from-mesh/241677/4',
#  'https://forums.developer.nvidia.com/u/dlindsey',
#  'https://forums.developer.nvidia.com/t/audio2face-2023-1-1-open-beta-released/260930/13',
#  'https://forums.developer.nvidia.com/t/slow-startup-time/187833/9',
#  'https://forums.developer.nvidia.com/t/unable-to-export-usd-file-to-local-nucleus-server/259199',
#  'https://forums.developer.nvidia.com/t/where-does-the-shader-cache-live-on-linux/248926/2',
#  'https://forums.developer.nvidia.com/t/product-configurator/261122/1',
#  'https://forums.developer.nvidia.com/t/requesting-a-community-extension/214982/3',
#  'https://forums.developer.nvidia.com/t/converting-the-example-to-a-standalone-application-using-jupyter-notebook-jupyter-notebook/256078/3',
#  'https://forums.developer.nvidia.com/t/general-omniverse-apps-launching-problem/255866/1',
# ...
#  'https://forums.developer.nvidia.com/t/error-in-installing-machinima-3-0/241614/7',
#  'https://forums.developer.nvidia.com/t/mtlx-primvar-reader-geo-property-value-is-supported-in-create/234545',
#  'https://forums.developer.nvidia.com/t/the-timeline-set-auto-update-false-no-longer-works/253504/10',
#  'https://forums.developer.nvidia.com/t/nucleus-is-stopped-and-it-does-not-start-runnung/255597',
#  'https://forums.developer.nvidia.com/t/sensors-tensorization-in-omniisaacgymenvs/255859/1',
#  'https://forums.developer.nvidia.com/t/welcome-to-the-omniverse-developer-forum/126444/2',
#  'https://forums.developer.nvidia.com/t/isaac-sim-inertia-treatment/253152',
#  'https://forums.developer.nvidia.com/t/problem-in-connecting-the-ros-bridge-to-a-real-robot-and-sending-the-message/253763',
#  'https://forums.developer.nvidia.com/t/color-each-side-of-the-cubeg/260266',
#  'https://forums.developer.nvidia.com/t/kit-105-how-to-get-early-access/258936/3',
#  'https://forums.developer.nvidia.com/t/isaac-sim-launch-stuck-after-rtx-ready/255917/13',
#  'https://forums.developer.nvidia.com/t/export-the-position-of-a-cylinder-as-a-python-variable/262128',
#  'https://forums.developer.nvidia.com/t/physics-and-simulation-parameters-for-grasping-and-picking-tasks-objects-slipping-away/259716/5',
#  'https://forums.developer.nvidia.com/t/trouble-importing-onshape-assembly-that-has-subassemblies/260609',
#  'https://forums.developer.nvidia.com/t/bboxcache-computation-is-wrong-during-pose-randomization/262190/1',
#  'https://forums.developer.nvidia.com/t/cannot-use-pointclouds-1-0-5-extension-on-create-xr-2022-2-0-rel-1/259304',
#  'https://forums.developer.nvidia.com/t/audio2face-headless-mode-error-when-export-blendshape/259793',
#  'https://forums.developer.nvidia.com/t/with-4-vdb-s-composer-is-still-crashing-quite-a-lot/262232',
#  'https://forums.developer.nvidia.com/t/how-to-set-prim-location-in-isaac-sim/259581/4',
#  'https://forums.developer.nvidia.com/t/how-to-use-real-time-lip-sync-on-unreal-engine-via-audio2face/243173/7',
#  'https://forums.developer.nvidia.com/t/open-audio2face-project-in-a-web-application/249508',
#  'https://forums.developer.nvidia.com/t/applying-transcluent-material-to-object-with-multiple-materials-turns-everything-black/258973',
#  'https://forums.developer.nvidia.com/t/access-to-world-object-or-simulationcontext-in-script-editor/257582',
#  'https://forums.developer.nvidia.com/t/moving-a-robots-arm-the-base-moves-along-but-shouldnt/258694',
#  'https://forums.developer.nvidia.com/t/the-nvidia-build-has-less-samplers/260367/2',
#  'https://forums.developer.nvidia.com/t/errors-with-hydra-scene-graph-instancing/257640',
#  'https://forums.developer.nvidia.com/t/bug-in-omni-anim-people-0-1-9/247584',
#  'https://forums.developer.nvidia.com/t/3d-connexion-mouse/170874/34',
#  'https://forums.developer.nvidia.com/t/new-nucleus-release-2023-1-0/256820/1',
#  'https://forums.developer.nvidia.com/t/adding-icons-in-extension/257619',
#  'https://forums.developer.nvidia.com/t/python-package-shapely-version-conflict/254132',
#  'https://forums.developer.nvidia.com/t/physics-in-vr/230518/9',
#  'https://forums.developer.nvidia.com/t/how-to-display-timeline-on-isaac-sim-interface/258124',
#  'https://forums.developer.nvidia.com/t/cannot-login-to-nucleus-server/244507',
#  'https://forums.developer.nvidia.com/t/i-still-see-black-reflections/256621/6',
#  'https://forums.developer.nvidia.com/t/mjcf-conversion-problem/257331',
#  'https://forums.developer.nvidia.com/t/wrong-credentials-or-the-user-does-not-exist/256659/2',
#  'https://forums.developer.nvidia.com/t/isaac-deformation/258332/2',
#  'https://forums.developer.nvidia.com/t/rendered-image-not-visible-camera-sensor-standalone-python-example/255585/12',
#  'https://forums.developer.nvidia.com/t/createjoint-no-bodies-defined-at-body-and-body1-joint-prim/253612/3',
#  'https://forums.developer.nvidia.com/t/new-release/257725/9',
#  'https://forums.developer.nvidia.com/t/materials-grayed-only-on-geometry-subsets-since-installing-update-2023-1-0/258457',
#  'https://forums.developer.nvidia.com/t/can-articulation-force-sensor-be-applied-to-manipulator/259267',
#  'https://forums.developer.nvidia.com/t/modding-isaac-jetbot-code-to-fit-city-environment/203089/3',
#  'https://forums.developer.nvidia.com/t/transferring-eye-tongue-and-jaw-animations-to-blendshape-model/261269/4',
#  'https://forums.developer.nvidia.com/t/asset-converter-cant-find-shapenet-png-textures/260233/1',
#  'https://forums.developer.nvidia.com/t/issue-in-simplifying-the-model/173547/8',
#  'https://forums.developer.nvidia.com/t/mirrors-are-not-handled-correctly-for-depth-of-field-simulation/253896/6',
#  'https://forums.developer.nvidia.com/t/conversational-ai-healthcare/255089/1',
#  'https://forums.developer.nvidia.com/t/physx-error-supplied-pxgeometry-is-not-valid/260265',
#  'https://forums.developer.nvidia.com/t/unreal-engine-speech-audio-to-audio2face/259045',
#  'https://forums.developer.nvidia.com/t/omniverse-code-extension-spawn-prim-with-non-standard-height-width-and-depth/259137',
#  'https://forums.developer.nvidia.com/t/export-usd-model-from-usd-composer-isaac-sim/258436',
#  'https://forums.developer.nvidia.com/t/time-to-move-camera-using-replicator-is-increasing-as-it-keeps-beeing-called/257438/6',
#  'https://forums.developer.nvidia.com/t/jittering-issues-pivot-tool-issues-and-objects-w-colliders-phasing-into-each-other/257586/4',
#  'https://forums.developer.nvidia.com/t/set-exact-intrinsic-matrix-of-camera-fails/257491/2',
#  'https://forums.developer.nvidia.com/t/isaac-sim-2022-2-1-doesnt-start/255476/11',
#  'https://forums.developer.nvidia.com/t/audio2face-unreal-export-custom-metahuman-head-from-unreal-with-blendshapes-for-blendshape-solve/256567',
#  'https://forums.developer.nvidia.com/t/how-to-properly-install-enterprise-launcher-on-a-local-network/258148',
#  'https://forums.developer.nvidia.com/t/could-not-login-the-omniverse-launcher/261003/3',
#  'https://forums.developer.nvidia.com/t/python-scripting-error/257256/3',
#  'https://forums.developer.nvidia.com/t/failed-to-upload-minidump-error-message-while-running-isaac-sim-from-docker/255949/3',
#  'https://forums.developer.nvidia.com/t/what-nvidia-educational-resources-do-i-start-with-for-the-purpose-needed-as-described/256552',
#  'https://forums.developer.nvidia.com/t/omniverse-toolbar-in-sketchup/257545/1',
#  'https://forums.developer.nvidia.com/t/how-to-solve-graph-composer-startup-errors/262290',
#  'https://forums.developer.nvidia.com/t/use-omniverse-api-to-add-camera-in-scene-got-rotation-problem/235208',
#  'https://forums.developer.nvidia.com/t/how-to-add-a-new-environment-in-isaac-sim/259232/4',
#  'https://forums.developer.nvidia.com/t/trouble-in-moveit2/262172/1',
#  'https://forums.developer.nvidia.com/t/usd-composer-2023-1-0-cannot-be-installed/258668',
#  'https://discord.com/invite/XWQNJDNuaC',
#  'https://forums.developer.nvidia.com/t/replicator-interactive-sdg-fruit-box-tutorial-on-local-machine/258815',
#  'https://forums.developer.nvidia.com/t/about-object-api/261918/1',
#  'https://forums.developer.nvidia.com/t/audio2face-no-mesh-showing-up/258438',
#  'https://forums.developer.nvidia.com/t/what-music-interferes-with-instructors-audio-adam-moravansky-tutorial-physics-ext-kit-104/256170/7',
#  'https://forums.developer.nvidia.com/t/error-starting-isaac-sim-from-docker/255239/4',
#  'https://forums.developer.nvidia.com/t/modelling-joint-motor-couplings-via-tendons/258206',
#  'https://forums.developer.nvidia.com/t/error-while-running-ros2-carter-navigation-example-no-tf-data-actual-error-frame-map-does-not-exist/249283/12',
#  'https://forums.developer.nvidia.com/t/consultation-needed/260995',
#  'https://forums.developer.nvidia.com/t/how-to-create-a-points/260230',
#  'https://forums.developer.nvidia.com/t/omniverse-code-dont-launch/260878/1',
#  'https://forums.developer.nvidia.com/t/mobile-manipulator-coupling-issue-in-isaac-sim-2022-2-0-version/256253/6',
#  'https://forums.developer.nvidia.com/t/strong-differences-behavior-cpu-gpu-gear-joints/256781/2',
#  'https://forums.developer.nvidia.com/t/glass-and-water-materials-can-i-stack-materials-on-top-of-each-other/256622',
#  'https://forums.developer.nvidia.com/t/turtlebot-joint-velocities-dont-match-the-desire-target-velocity/220383',
#  'https://forums.developer.nvidia.com/t/failed-to-download-audio2face/257338',
#  'https://forums.developer.nvidia.com/t/can-i-now-import-alembic-data/256378/8',
#  'https://forums.developer.nvidia.com/t/how-to-introduce-a-new-usd-schema-that-built-in-c-dll-into-omniverse/201042/12',
#  'https://forums.developer.nvidia.com/t/unexpected-robot-movement-in-environment-with-sdf-based-collision-and-fixed-joints/259703/3',
#  'https://forums.developer.nvidia.com/t/how-to-transfer-the-isaac-sim-cortex-work-from-isacc-sim-2022-1-1-to-isacc-sim-2022-2-0/249426/6',
#  'https://forums.developer.nvidia.com/t/nucleus-hell/260655/2',
#  'https://forums.developer.nvidia.com/t/navmmesh-issue-with-warehouse-usd/255295/2',
#  'https://forums.developer.nvidia.com/t/maya-connector-native-viewport-material-preview-best-way-to-export-materials/258596',
#  'https://forums.developer.nvidia.com/t/modulenotfound-importing-python-kit-modules-into-connectorsample/260516/1',
#  'https://forums.developer.nvidia.com/t/create-install-stuck-on-omni-create-warmup-bat/256165/4',
#  'https://forums.developer.nvidia.com/t/omniverse-blog-posts/235727',
#  'https://forums.developer.nvidia.com/t/maya-2024-mayaomniverse-connector/251317/3',
#  'https://forums.developer.nvidia.com/t/diffrential-controller-speed/259496/2',
#  'https://forums.developer.nvidia.com/t/modulenotfounderror-no-module-named-subprocess-isaacsim-2022-2-1-crash-suddenly-appeared/258555',
#  'https://forums.developer.nvidia.com/t/issac-sim-people-simulation-character-initialization/255974',
#  'https://forums.developer.nvidia.com/t/bugreport-on-machinima-2022-3-0-beta-solution/260407',
#  'https://forums.developer.nvidia.com/t/multi-line-editor-widget/255063',
#  'https://forums.developer.nvidia.com/t/asset-converter-cant-find-shapenet-png-textures/260233',
#  'https://forums.developer.nvidia.com/t/imu-topic-publish-code-error/247641',
#  'https://forums.developer.nvidia.com/t/nvidia-joins-alliance-for-openusd-aousd/261743/1',
#  'https://forums.developer.nvidia.com/t/using-imu-in-rl-learning-training-for-a-walking-biped/259225/7',
#  'https://forums.developer.nvidia.com/t/lula-target-position-is-in-world-coordinates-but-orientation-is-relative-to-robot-base/260944/2',
#  'https://forums.developer.nvidia.com/t/big-shout-to-get-stability-in-isaacsim/253536/5',
#  'https://forums.developer.nvidia.com/t/audio2face-emotions-in-streaming-livelink-error/262343/1',
#  'https://forums.developer.nvidia.com/t/how-to-use-randomizer-tool-on-surface-instancer/257163/2',
#  'https://forums.developer.nvidia.com/t/isaac-sim-omnigraph-read-imu-node-index-out-of-bounds/241304',
#  'https://forums.developer.nvidia.com/t/ibis-model-for-rtx-a2000-display-port-1-4/261753',
#  'https://forums.developer.nvidia.com/t/closed-articulation-simulation-problem/258431/4',
#  'https://forums.developer.nvidia.com/t/access-to-cpython-sensor-code-or-low-level-object-collision-information-to-model-custom-contact-sensor/257565/10',
#  'https://forums.developer.nvidia.com/t/how-can-i-turn-off-snap-widget-ui/243729/3',
#  'https://forums.developer.nvidia.com/t/waiting-for-compilation-of-ray-tracing-shaders-by-gpu-driver-on-ubuntu-22-04/256811/1',
#  'https://forums.developer.nvidia.com/t/extensions-are-not-loading/259220',
#  'https://forums.developer.nvidia.com/t/isaac-sim-2022-2-1-release-is-out-and-live-now/246776/3',
#  'https://forums.developer.nvidia.com/t/urdf-importer-and-articulation-trouble/256708',
#  'https://forums.developer.nvidia.com/t/the-timeline-set-auto-update-false-no-longer-works/253504',
#  'https://forums.developer.nvidia.com/t/isaac-sim-could-not-be-launched/256443',
#  'https://forums.developer.nvidia.com/t/i-created-a-server-i-think-but-i-dont-know-my-server-name/261882',
#  'https://forums.developer.nvidia.com/t/ibis-model-for-rtx-a2000-display-port-1-4/261753/1',
#  'https://forums.developer.nvidia.com/t/change-pivot-not-working/255834/2',
#  'https://forums.developer.nvidia.com/t/errors-with-articulation-inspector-while-moving-a-robot-imported-from-an-external-urdf/255087',
#  'https://forums.developer.nvidia.com/t/open-connection-for-writer-syncgate/255737',
#  'https://forums.developer.nvidia.com/t/how-to-use-differential-controller-with-acceleration-limit/256305/2',
#  'https://forums.developer.nvidia.com/u/hombrezoo',
#  'https://forums.developer.nvidia.com/t/script-usdgeomxformable-placement-and-visibility-on-timeline/253353',
#  'https://forums.developer.nvidia.com/t/3dsmax-2023-exporting-models-with-instances-and-broken-shaders/233673/7',
#  'https://forums.developer.nvidia.com/t/can-nvidia-gup-a40-deploy-isaac-sim/256755/2',
#  'https://forums.developer.nvidia.com/t/rtx-real-time-opacity-material/258680',
#  'https://forums.developer.nvidia.com/t/video-textures/163939',
#  'https://forums.developer.nvidia.com/u/formalemailptk',
#  'https://forums.developer.nvidia.com/t/not-able-to-sign-in-revit-omniverse-connector-file-transferring-failed/253776',
#  'https://forums.developer.nvidia.com/t/speed-up-the-simulation/244701',
#  'https://forums.developer.nvidia.com/t/is-there-a-simpler-example-on-how-rl-environment-works-in-isaac-sim-and-gym/256300',
#  'https://forums.developer.nvidia.com/t/rtx-lidar-sdg-without-script-editor/260006',
#  'https://forums.developer.nvidia.com/t/sclect-xform-case-robot-move-when-importing-urdf/259675/4',
#  'https://forums.developer.nvidia.com/t/conversational-ai-healthcare/255089',
#  'https://forums.developer.nvidia.com/t/import-robotiq-2f-85-urdf-in-isaac-sim/203736',
#  'https://forums.developer.nvidia.com/t/issue-in-simplifying-the-model/173547',
#  'https://forums.developer.nvidia.com/t/animation-graphs-and-world-position-how-to-make-it-local-space/259008',
#  'https://forums.developer.nvidia.com/t/nucleus-connection-to-the-local-host/254708',
#  'https://forums.developer.nvidia.com/t/demo-availability/213697/6',
#  'https://forums.developer.nvidia.com/t/from-omniverse-to-sketchfab/202739',
#  'https://forums.developer.nvidia.com/t/use-of-3dconnection-mouse-device-in-omniverse/223659/3',
#  'https://forums.developer.nvidia.com/t/how-to-permanently-attach-the-camera-on-franka-panda-end-effector/259868/2',
#  'https://forums.developer.nvidia.com/t/crash-during-suspension/260646/1',
#  'https://forums.developer.nvidia.com/t/can-articulation-force-sensor-be-applied-to-manipulator/259267/6',
#  'https://forums.developer.nvidia.com/t/omniverse-launcher-resets-start-up-application-status-on-reboot/255778',
#  'https://forums.developer.nvidia.com/t/no-keyframe-animation-coming-to-blender-from-composer/257675/1',
#  'https://forums.developer.nvidia.com/t/multi-robot-navigation-example-doesnt-work/257560',
#  'https://forums.developer.nvidia.com/t/whats-the-eta-for-omniverse-unreal-engine-5-2-connector-please/261608',
#  'https://forums.developer.nvidia.com/t/isaac-sim-startup-error-cannot-load-cublas-dll/219165',
#  'https://forums.developer.nvidia.com/t/maya-arnold-error/233498/2',
#  'https://forums.developer.nvidia.com/t/unclear-unit-update-simulation-elapsed-time/261843',
#  'https://forums.developer.nvidia.com/t/how-to-create-a-points/260230/2',
#  'https://forums.developer.nvidia.com/t/instancing/256629/2',
#  'https://forums.developer.nvidia.com/t/get-list-of-objects-in-a-scene/261400',
#  'https://forums.developer.nvidia.com/t/creating-a-web-based-virtual-tour/258573',
#  'https://forums.developer.nvidia.com/u/WendyGram',
#  'https://forums.developer.nvidia.com/t/usd-composer-2023-1-0-cannot-be-installed/258668/23',
#  'https://forums.developer.nvidia.com/t/isaac-sim-2022-2-1-bult-in-quadruped-example-crash-on-loading-to-the-world/261434',
#  'https://forums.developer.nvidia.com/t/nvidia-folder-lock-in-the-local-host/260542/2',
#  'https://forums.developer.nvidia.com/t/how-to-interface-usd-compser-and-legacy-system/259679',
#  ...]

# %%
print(len(forum_links))
# Out:
# 2029

# %%
print(forum_links[-3])
# Out:
# https://forums.developer.nvidia.com/t/can-i-run-isaac-ros-on-jetson-and-get-the-image-and-data-from-x86-isaac-sim/255336

# %%
def contains_numbers(s):
    return  s.isdigit()

# %%
forum_data = {}


    
for link in forum_links:
    if str(link).startswith('https://forums.developer.nvidia.com/t/'):
        
        query_name = None
        if (contains_numbers(list(str(link).split('/'))[-2])):
            query_name = list(str(link).split('/'))[-3]
        else:
            query_name = list(str(link).split('/'))[-2]
            
            
        
        url = str(link)
        response = requests.get(url)
        soup = BeautifulSoup(response.content, "html.parser")
        paragraphs = soup.find_all("p")


        total_text = ''
        for paragraph in paragraphs:
            text = paragraph.get_text()
            total_text = total_text + text

        forum_data[query_name] = total_text

# %%
len(forum_data)

# %%
keys = list(forum_data.keys())
values= list(forum_data.values())
data = {
    'query': keys,
    'data': values
    
}

# %%
df = pd.DataFrame(data)


# Display the DataFrame
df

# %%
df.to_csv('omniverse.csv')
